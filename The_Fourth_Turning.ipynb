# %% [markdown]
# # The Fourth Turning
# ### What the Cycles of History Tell Us About America's Next Rendezvous with Destiny
# #### by William Strauss and Neil Howe
#
# ### “Every Fourth Turning since the fifteenth century has culminated in total war… America’s old civic order will seem ruined beyond repair... The very survival of the nation will feel at stake. Sometime before the year 2025.”
#
# That statement, which seems to understand the trajectory of current events in 2020 and 2021 so well, is a prediction that was actually published in 1997 – more than 20 years ago.

# %%
from IPython.display import Image
from pathlib import Path
home_path = Path.home() / 'Jupyter' / 'Fourth_Turning' / 'Fourth_Turning'
Image(filename= home_path / 'Cover_The_Fourth_Turning.jpg')

# %% [markdown]
# Authors William Strauss and Neil Howe are widely credited with naming the Millennial generation (see: https://en.wikipedia.org/wiki/Millennials). They are foremost experts and researchers on Generational identities, and have advanced a compelling theory of American history. In one sentence, the theory is that American history has exhibited a cycle, or seasonality, that is intertwined with the lifecycles of the changing generations as they move throughout time. A life, and a Generation lives for about 80-years, so too does the cycle of American history. The authors published a sobering prediction, and the historical precedents for the Crisis we are navigating today.
#
# ### Project Description:
#
# This project seeks to retell their story through data. The data used in this analysis reorganizes America’s political leadership through their generational identities and reorganizes America’s economic trajectory through the lens of Turnings (or "seasons").
#
# The Fourth Turning narrative is incredibly compelling, with anecdotes and facts that help organize the 10,000ft view presented to us.  However, I want to visualize their story through time: What did the prior cycles really look like, and where does that put us today?
#
# ### The Data:
#
# * American political leadership data includes Presidents and members of Congress from 1789 to the present (2018 – not 2020 yet). The data comes from the @unitedstates project on GitHub, with notable supporters of the database being FiveThirtyEight, GovTrack, ProPublica, and The New York Times. All 67 terms served by presidents (whether the full 4-years or abbreviated) and a total of 41,618 members of Congress are included, although 1,165 (~3%) of Congressional members are missing birthdate information, which prevents any generational analysis.
#
# The economic data include U.S. GDP-per-Capita, population growth, and Federal Debt-to-GDP.
# * The measure of real GDP per capita – adjusting for inflation – comes from the venerable Maddison Project Database, part of University of Groningen, Netherlands. Real GDP-per-Capita is arguably the most prevalent development statistic used to measure a nation – capturing the scale of output and income. The data is available in a 1-year interval beginning in 1800, so that is what is used. The Maddison Project Database is referenced by publications out of Oxford, the University of Chicago, and Stanford (see the links below for reference).
#
# * Data covering the U.S. Federal Government’s Debt-to-GDP from 1790 through today comes from the U.S. Congressional Budget Office. While Debt-to-GDP does not capture the entire store of social liabilities - there are health care burdens, pension burdens, and corporate and consumer debt - it does tell a large part of the story, and one that is directly impacted by the decisions of America's leadership.
#
# The book’s website was used for definitions of Generation and Turnings,  both the timeline of their range of years and their archetypes within the cycle.

# %% [markdown]
# ### A Brief Summary:
#
# If you have not read the book, here is a very helpful, recent 5-minute clip from CNBC on April-2020. And a written summary below:
# * https://www.cnbc.com/video/2020/04/24/theorist-us-rolls-in-80-year-cycles-and-now-is-the-next-reconstruction.html

# %% [markdown]
# ### American history follows a cyclicality, a seasonality...
# The theory is that history, specifically American history, follows a cyclical pattern, analogous in many ways to nature's seasons: Winter, Spring, Summer, and Fall. The Winter is a Crisis period – which has coincided with the major wars of the American Revolution, the Civil War, and World War II. Spring is the post-war boom (ex. 1950’s), Autumn is the pre-war unraveling, and Summer is a cultural awakening (ex. the counter-culture revolution of the 1960's and American history's major religious "awakenings": the First Great Awakening 1730's, Second Great Awakening in 1790's, and the Third Great Awakening in the 1890's).
#
# ### ...As each generation has a unique persona, which is shaped by history in their youth...
# These four seasons of history span the length of a typical generation (about 20 years) and combine to about 80-years, the span of a human life. The phenomenon of generations and their unique identities, is fundamentally intertwined with this historical seasonality and cyclicality. Generational identities are shaped by the events of history in their youth years, and later in life they, in-turn shape the events of history.
#
# ### ...And shapes history in adulthood.
# A pattern emerges. As each generation ages and transitions to the next stage of life (Child to Young Adult, to Midlife, to Elderhood), history too transitions to the next phase of the cycle, the next season of history. And while history tends to look very different from one season to the next, just as a generation tends to look very different from one to the next, history does tends to rhyme when viewed from a longer timeline.

# %% [markdown]
# A longer presentation by Neil Howe was given at a St. Louis Fed conference in 2014; focusing on Generational identities more so than Turnings:
#
# * https://www.stlouisfed.org/household-financial-stability/events/past-events/the-balance-sheets-of-younger-americans/videos/keynote-address

# %% [markdown]
# ### Resources:
#
# Primary Resources:
# * List of Congressional Legistaltors from 1789 to Present:
#     * https://github.com/unitedstates/congress-legislators
# * Biographical Directory of the United States Congress, 1774–Present
#     * https://bioguide.congress.gov/search
# * The Fourth Turning:
#     * American Leadership Database:  https://www.lifecourse.com/goal/overview.php
#     * Generations:  https://www.lifecourse.com/about/method/timelines/generations.html
#     * Seasons/Periods:  https://www.lifecourse.com/about/method/the-four-turnings.html
# * GDP-per-Capita and Population Growth: Maddison Project Database 2020
#     * https://www.rug.nl/ggdc/historicaldevelopment/maddison/releases/maddison-project-database-2020?lang=en
#     * As also referenced by:
#         * Oxford: https://ourworldindata.org/economic-growth
#         * U. Chicago: https://bfi.uchicago.edu/insight/chart/u-s-real-gdp-per-capita-1900-2017-current-economy-vs-historical-trendline/
#         * Stanford: https://web.stanford.edu/~chadj/facts.pdf
# * Congressional Budget Office (CBO): Historical Data on Federal Debt Held by the Public
#     * https://www.cbo.gov/publication/56165
# * Inequality datasets:
#     * Global Price and Income History Group, by Peter H. Lindert
#         * Source: http://gpih.ucdavis.edu/tables.htm
#     * World Inequality Database: by Emmanuel Saez and Thomas Piketty
#         * Source:  https://wid.world/
#
# Other Resources:
# * Pew Research:
#     * https://www.pewresearch.org/topics/generations-and-age/
# * National Governors Association
#     * https://www.nga.org/former-governors/
# * Other Resource:
#     * PoliticalGraveyard.com

# %%
import numpy as np
import pandas as pd
# import pandas_datareader.data as pdr
import requests

# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
#plt.style.use('seaborn')  
sns.set()

from datetime import datetime
today = datetime.now()
month,day,year = today.month,today.day,today.year

# %%
# ! pip install pyyaml

import yaml
import io

# %%
# Convert YAML to DataFrame
def yaml_to_df(yaml_data):
    data_list = []
    for index, entry in enumerate(yaml_data):
        for term, entry_terms in enumerate(entry['terms']):
            try:
                _birthday = entry['bio']['birthday']
            except KeyError:
                _birthday = 'NaT'
            try:
                _party = entry_terms['party']
            except KeyError:
                _party = 'NaN'
            
            data_list.append({
                'Name': ('_'.join([entry['name']['first'], entry['name']['last']])),
                'Birthday': _birthday,
                'Job': entry_terms['type'],
                'Start': entry_terms['start'],
                'End': entry_terms['end'],
                'Party': _party,
            })
    data_df = pd.DataFrame(data_list)
    return data_df

# %% [markdown]
# ### Political Leadership

# %%
# Presidents:  https://theunitedstates.io/congress-legislators/executive.yaml
# Congress: https://theunitedstates.io/congress-legislators/legislators-historical.yaml

presidents_url = 'https://theunitedstates.io/congress-legislators/executive.yaml'
congress_url = 'https://theunitedstates.io/congress-legislators/legislators-historical.yaml'


def url_to_yaml(url):    
    res = requests.get(url)
    res.raise_for_status() 
    yaml_data = yaml.safe_load(res.content)
    return yaml_data

# %%
# Download YAML from GitHub website, process into a DataFrame

yaml_executive = url_to_yaml(presidents_url)
yaml_congress = url_to_yaml(congress_url)
    
executive_df = yaml_to_df(yaml_executive)
congress_df = yaml_to_df(yaml_congress)

# %% [markdown]
# #### Political Leadership: the President

# %%
executive_df[executive_df['Birthday'] == 'NaT']
# Out:
#                  Name Birthday   Job       Start         End       Party
# 77     Herbert_Hoover      NaT  prez  1929-03-04  1933-03-04  Republican
# 89  Dwight_Eisenhower      NaT  prez  1953-01-20  1957-01-20  Republican
# 90  Dwight_Eisenhower      NaT  prez  1957-01-20  1961-01-20  Republican

# %%
# Fix missing Birthdays
# Dwight_David_Eisenhower:  October 14, 1890
# Herbert_Hoover:  August 10, 1874

birthday_fix_dict = {'Dwight_Eisenhower': '1890-10-14',
                    'Herbert_Hoover': '1874-08-10'}
for index, name in enumerate(birthday_fix_dict.keys()):
    executive_df.loc[executive_df['Name'] == name, 'Birthday'] = birthday_fix_dict[name]

# %%
# Convert dates to DateTime format

columns_date_time = ['Birthday', 'Start', 'End']
for index, cols in enumerate(columns_date_time):
    #print(cols)
    executive_df[cols] = pd.to_datetime(executive_df[cols], infer_datetime_format=True)

# %% [markdown]
# #### The Fourth Turning: Generations

# %%
# The Fourth Turning: Generations

generation_url = 'https://www.lifecourse.com/about/method/timelines/generations.html'
generation_df = pd.read_html(generation_url, header=1)[0]

generation_df[['Start', 'End']] = generation_df['Birth Years'].str.split('\D', n=1, expand=True)
generation_df['Start_dt'] = pd.to_datetime(generation_df['Start'], infer_datetime_format=True, errors='coerce')
#generation_df['End_dt'] = pd.to_datetime(generation_df['End'], infer_datetime_format=True, errors='coerce')

# Create an IntervalIndex
generation_df = generation_df.dropna(axis=0, subset=['Start_dt'])  # how='any'
generation_df.index = pd.IntervalIndex.from_breaks(
    # HardCode: Set birthdate range for Homelanders (20-years)  ('2025-01-01')  
    generation_df['Start_dt'].append(pd.Series(pd.to_datetime('2025-01-01')), ignore_index=True), 
    closed='left')

# %%
generation_df.drop(columns=['Start', 'End', 'Start_dt'])  # Just to visualize
#generation_df
# Out:
#                               Generation Birth Years                      Man  \
# [1701-01-01, 1724-01-01)       Awakening   1701–1723         Jonathan Edwards
# [1724-01-01, 1742-01-01)         Liberty   1724–1741        George Washington
# [1742-01-01, 1767-01-01)      Republican   1742–1766         Thomas Jefferson
# [1767-01-01, 1792-01-01)      Compromise   1767–1791           Andrew Jackson
# [1792-01-01, 1822-01-01)  Transcendental   1792–1821          Abraham Lincoln
# [1822-01-01, 1843-01-01)          Gilded   1822–1842            Ulysses Grant
# [1843-01-01, 1860-01-01)     Progressive   1843–1859           Woodrow Wilson
# [1860-01-01, 1883-01-01)      Missionary   1860–1882       Franklin Roosevelt
# [1883-01-01, 1901-01-01)            Lost   1883–1900             Harry Truman
# [1901-01-01, 1925-01-01)            G.I.   1901–1924             John Kennedy
# [1925-01-01, 1943-01-01)          Silent   1925–1942  Martin Luther King, Jr.
# ...

# %%
# President:  Merge Generational Info with Executive Leaders:

executive_df['Archetype'] = executive_df['Birthday'].map(generation_df['Archetype'])
executive_df['Generation'] = executive_df['Birthday'].map(generation_df['Generation'])

executive_df = executive_df.set_index(['Start', 'End'])
executive_df.index = pd.IntervalIndex.from_tuples(executive_df.index)

president_df = executive_df[executive_df['Job'] == 'prez']
vice_president_df = executive_df[executive_df['Job'] == 'viceprez']

# %%
president_df
# Out:
#                                        Name   Birthday   Job  \
# (1789-04-30, 1793-03-04]  George_Washington 1732-02-22  prez
# (1793-03-04, 1797-03-04]  George_Washington 1732-02-22  prez
# (1797-03-04, 1801-03-04]         John_Adams 1735-10-19  prez
# (1801-03-04, 1805-03-04]   Thomas_Jefferson 1743-04-13  prez
# (1805-03-04, 1809-03-04]   Thomas_Jefferson 1743-04-13  prez
# ...                                     ...        ...   ...
# (2005-01-20, 2009-01-20]        George_Bush 1946-07-06  prez
# (2009-01-20, 2013-01-20]       Barack_Obama 1961-08-04  prez
# (2013-01-20, 2017-01-20]       Barack_Obama 1961-08-04  prez
# (2017-01-20, 2021-01-20]       Donald_Trump 1946-06-14  prez
# (2021-01-20, 2025-01-20]       Joseph_Biden 1942-11-20  prez
#
#                                           Party Archetype    Generation
# (1789-04-30, 1793-03-04]               no party     Nomad       Liberty
# (1793-03-04, 1797-03-04]               no party     Nomad       Liberty
# ...

# %% [markdown]
# #### The Fourth Turning: Periods and Turnings

# %%
# The Fourth Turning: Periods/Turnings

#saeculum_url = 'https://www.lifecourse.com/about/method/the-four-turnings.html'
period_url = 'https://www.lifecourse.com/about/method/timelines/turnings.html'
period_df = pd.read_html(period_url, header=1, index_col=0)[0]

new_columns_period = ['First_Turning', 'Second_Turning', 'Third_Turning', 'Fourth_Turning']
_period_df = period_df[6:]
_period_df.columns = new_columns_period
_period_df
# Out:
#                                            First_Turning  \
# Late Medieval                                          —
# Tudor                     Tudor Renaissance  (1487–1517)
# New World                    Merrie England  (1594–1621)
# Revolutionary        Augustan Age of Empire  (1704–1727)
# Civil War              Era of Good Feelings  (1794–1822)
# Great Power    Reconstruction  & Gilded Age  (1865–1886)
# Millennial                    American High  (1946–1964)
#
#                                       Second_Turning  \
# Late Medieval                                      —
# Tudor            Protestant Reformation  (1517–1542)
# New World             Puritan Awakening  (1621–1649)
# Revolutionary           Great Awakening  (1727–1746)
# Civil War      Transcendental Awakening  (1822–1844)
# Great Power       Third Great Awakening  (1886–1908)
# Millennial     Consciousness Revolution  (1964–1984)
#
#                                          Third_Turning  \
# ...

# %%
import re

period_regex = re.compile('(.*)\s\((\d{4}).(\d{4}).?\)')  # '(.*)\s\((\d{4}).(\d{4}).?\)'
# Resource: https://regex101.com/

turnings_list = [];  # saeculum_list = []
for turning, _periods in _period_df.iteritems():
    for saeculum, _string in _periods.iteritems():
        _regex_match = re.search(period_regex, _string)
        if _regex_match is not None:
            period, start, end = _regex_match.groups()
            turnings_list.append({'Turning': turning, 'Period': period.rstrip(), 'Saeculum': saeculum, 
                                  'Start': start, 'End': end})
        pass
    pass

turnings_df = pd.DataFrame(turnings_list)

# %%
# Drop pre-American Revolution Turnings (no data availabel for President/Congress or GDP-per-Capita)
turnings_df = turnings_df.sort_values('Start', ascending=True).reset_index(drop=True)
_index = turnings_df[turnings_df['Period'] == 'American Revolution'].index
turnings_df = turnings_df[_index[0]:]

# %%
turnings_df
# Out:
#            Turning                           Period       Saeculum Start   End
# 13  Fourth_Turning              American Revolution  Revolutionary  1773  1794
# 14   First_Turning             Era of Good Feelings      Civil War  1794  1822
# 15  Second_Turning         Transcendental Awakening      Civil War  1822  1844
# 16   Third_Turning       Mexican War & Sectionalism      Civil War  1844  1860
# 17  Fourth_Turning                        Civil War      Civil War  1860  1865
# 18   First_Turning     Reconstruction  & Gilded Age    Great Power  1865  1886
# 19  Second_Turning            Third Great Awakening    Great Power  1886  1908
# 20   Third_Turning        World War I & Prohibition    Great Power  1908  1929
# 21  Fourth_Turning  Great Depression & World War II    Great Power  1929  1946
# 22   First_Turning                    American High     Millennial  1946  1964
# 23  Second_Turning         Consciousness Revolution     Millennial  1964  1984
# ...

# %%
# Unpack Years (defined by year-end)

#_turnings_df = turnings_df.copy()
_years = pd.to_datetime(turnings_df['Start'], errors='coerce', format='%Y')
turnings_df['Start_dt'] = _years + pd.tseries.offsets.YearEnd()

_years = pd.to_datetime(turnings_df['End'], errors='coerce', format='%Y')
turnings_df['End_dt'] = _years + pd.tseries.offsets.YearEnd()
turnings_df = turnings_df.dropna(how='any')

turnings_df[turnings_df['Turning'] == 'First_Turning']
# Out:
#           Turning                        Period     Saeculum Start   End  \
# 14  First_Turning          Era of Good Feelings    Civil War  1794  1822
# 18  First_Turning  Reconstruction  & Gilded Age  Great Power  1865  1886
# 22  First_Turning                 American High   Millennial  1946  1964
#
#      Start_dt     End_dt
# 14 1794-12-31 1822-12-31
# 18 1865-12-31 1886-12-31
# 22 1946-12-31 1964-12-31

# %%
# Archetype Lookup: 

new_columns_period = ['First_Turning', 'Second_Turning', 'Third_Turning', 'Fourth_Turning']
archetype_df = period_df[1:5]
archetype_df.columns = new_columns_period

# Add Scores: 
_archetypes = archetype_df.index
_score_exec = list(range(1, 4)) + [0]
_score_congress = [0, 1, 1, 0]  # Alternative:  [0, 1, 2, 0]

archetype_df = archetype_df.join(pd.Series(_score_exec, index=_archetypes, name='Score_Exec', dtype=int))
archetype_df = archetype_df.join(pd.Series(_score_congress, index=_archetypes, name='Score_Congress', dtype=int))
archetype_df
# Out:
#                 First_Turning Second_Turning Third_Turning Fourth_Turning  \
# Elderhood               Nomad           Hero        Artist        Prophet
# Midlife                  Hero         Artist       Prophet          Nomad
# Young Adulthood        Artist        Prophet         Nomad           Hero
# Childhood             Prophet          Nomad          Hero         Artist
#
#                  Score_Exec  Score_Congress
# Elderhood                 1               0
# Midlife                   2               1
# Young Adulthood           3               1
# Childhood                 0               0

# %%
# Civil War Saelculum: Visualize that there is no Hero Generation - for three Turnings

# pd.read_excel(home_path / 'Civil_War_Saeculum.xlsx', sheet_name='Visualize_Basic', header=5, index_col=0)
Image(filename= home_path / 'Civil_War_Saeculum.png')

# %%
# Civil War Saelculum:

civil_war_saeclum_list = ['Civil War', 'Reconstruction  & Gilded Age', 'Third Great Awakening']
civil_war_saeclum_dict = {'Civil War': ['Artist', 'Prophet', 'Nomad', 'Hero'],
                          'Reconstruction  & Gilded Age': ['Prophet', 'Nomad', 'Artist', 'Hero'],
                          'Third Great Awakening': ['Nomad', 'Artist', 'Prophet', 'Hero']}

civil_war_saeclum_df = archetype_df[['Score_Exec', 'Score_Congress']].join(
    pd.DataFrame.from_dict(civil_war_saeclum_dict, orient='index', columns=_archetypes).T)
civil_war_saeclum_df
# Out:
#                  Score_Exec  Score_Congress Civil War  \
# Elderhood                 1               0    Artist
# Midlife                   2               1   Prophet
# Young Adulthood           3               1     Nomad
# Childhood                 0               0      Hero
#
#                 Reconstruction  & Gilded Age Third Great Awakening
# Elderhood                            Prophet                 Nomad
# Midlife                                Nomad                Artist
# Young Adulthood                       Artist               Prophet
# Childhood                               Hero                  Hero

# %%
def construct_timeline(turnings_df):
    turnings_dict = {}  # Dictionary of DataFrames, one for each Turning
    # Loop through each Turning
    for index_turnings, name_turnings in enumerate(turnings_keys):
        # name_turnings = ['First_Turning', 'Second_Turning', 'Third_Turning', 'Fourth_Turning']
        tgt_turning = turnings_df[turnings_df['Turning'] == name_turnings]
        # Construct the Pivot Table
        timeline_turning_df = pd.DataFrame()
        # Loop through each Period, in the specifit Turning
        for index in range(tgt_turning.shape[0]):
            # X-Axis for lookup: individual Years, in each period in each specific Turning
            _index = pd.date_range(start=tgt_turning['Start_dt'].iloc[index], 
                                   end=tgt_turning['End_dt'].iloc[index], freq='Y', name='Year')
            # X-Axis for plotting: number of years since start of period
            _column_count = np.arange(0,_index.size)
            _column_period = [tgt_turning['Period'].iloc[index]] * _index.size
            timeline_turning_df = (timeline_turning_df
                                   .append(pd.DataFrame(_column_count, index=_index, columns=['Year_Count'])
                                           .join(pd.DataFrame(_column_period, index=_index, columns=['Period']))
                                          ))
        timeline_turning_df = timeline_turning_df.reset_index()
        turnings_dict[name_turnings] = timeline_turning_df
    return turnings_dict

# %%
# Build a Pivot Table (for each Turning):

#turnings_keys = list(turnings_df['Turning'].unique())
turnings_keys = ['First_Turning', 'Second_Turning', 'Third_Turning', 'Fourth_Turning']
turnings_dict = construct_timeline(turnings_df)

# %%
# Construct Executive-branch Pivot Table: through a loop

exec_pivot_turnings_dict = {}
exec_turnings_dict = {}
for index_turnings, name_turnings in enumerate(turnings_keys):
    timeline_turning_df = turnings_dict[name_turnings].copy()
    # Executive-specific Construction
    timeline_turning_df['President'] = timeline_turning_df['Year'].map(president_df['Name'])
    timeline_turning_df['Archetype'] = timeline_turning_df['Year'].map(president_df['Archetype'])
    timeline_turning_df = timeline_turning_df.dropna(how='any').set_index('Year')
    # Executive-specific Score calculation
    for i in range(timeline_turning_df.shape[0]):
        if timeline_turning_df['Period'].iloc[i] in civil_war_saeclum_list:
                    exec_score_df = (civil_war_saeclum_df[[timeline_turning_df['Period'].iloc[i], 'Score_Exec']]
                                     .set_index(timeline_turning_df['Period'].iloc[i]))
        else:
            exec_score_df = archetype_df[[name_turnings, 'Score_Exec']].set_index(name_turnings)
    #exec_score_df = archetype_df[[name_turnings, 'Score_Exec']].set_index(name_turnings)
    
    timeline_turning_df['Score'] = timeline_turning_df['Archetype'].map(exec_score_df['Score_Exec'])
    timeline_turning_pivot = timeline_turning_df.pivot(index='Year_Count', columns='Period', values='Score')
    
    exec_turnings_dict[name_turnings] = timeline_turning_df
    exec_pivot_turnings_dict[name_turnings] = timeline_turning_pivot

# %%
# Presidents: Comparison of Periods within a Turnings, and accross Turnings 
figure_1, ax = plt.subplots(nrows=4, ncols=1, figsize=(15, 15), sharex=True);
cmap = sns.color_palette("Blues", as_cmap=True) # PuOr, viridis, PRGn, RdBu, icefire
for i in range(4):
    pivot_table = exec_pivot_turnings_dict[turnings_keys[i]]
    pivot_table.plot(ax=ax[i], colormap=cmap, linewidth=5);
    plt.ylabel('Score',fontsize=15);
    plt.xlabel('Years into new Turning/Period',fontsize=15);
    ax[i].set_title(turnings_keys[i], fontsize=20);
print('Generation of U.S. Presidents - Comparison Accross Turnings')
plt.show()
# Out:
# Generation of U.S. Presidents - Comparison Accross Turnings

# %% [markdown]
# #### Data Quality Note:
#
# The bilip in the 'Mexican War and Sectionalism' period is not an error. Zachary Talor was elected the 12th president of the United States, serving from March 1849 until his death in July 1850.

# %%
# The bilip in the 'Mexican War and Sectionalism' period is not an error 

(exec_turnings_dict['Third_Turning'][exec_turnings_dict['Third_Turning']['Period'] 
                                     == 'Mexican War & Sectionalism'].head(8))
# Out:
#             Year_Count                      Period         President  \
# Year
# 1844-12-31           0  Mexican War & Sectionalism        John_Tyler
# 1845-12-31           1  Mexican War & Sectionalism        James_Polk
# 1846-12-31           2  Mexican War & Sectionalism        James_Polk
# 1847-12-31           3  Mexican War & Sectionalism        James_Polk
# 1848-12-31           4  Mexican War & Sectionalism        James_Polk
# 1849-12-31           5  Mexican War & Sectionalism    Zachary_Taylor
# 1850-12-31           6  Mexican War & Sectionalism  Millard_Fillmore
# 1851-12-31           7  Mexican War & Sectionalism  Millard_Fillmore
#
#            Archetype  Score
# Year
# 1844-12-31    Artist      1
# 1845-12-31   Prophet      2
# 1846-12-31   Prophet      2
# 1847-12-31   Prophet      2
# 1848-12-31   Prophet      2
# 1849-12-31    Artist      1
# 1850-12-31   Prophet      2
# 1851-12-31   Prophet      2

# %%
# Scoring: Executive

avg_score_df = pd.DataFrame()
first_score_2_df = pd.DataFrame()
for i in range(4):  # Loop through Turnings 
    pivot_table = exec_pivot_turnings_dict[turnings_keys[i]]

    # 1) Values:
    _turning_score_details_df = pd.DataFrame(pivot_table.mean(), columns=[turnings_keys[i]])
    _mean = pd.Series(_turning_score_details_df.mean(), name='Mean')
    _var = pd.Series(_turning_score_details_df.var(), name='Var')
    _count = pd.Series(_turning_score_details_df.count(), name='Count')
    avg_score_df = avg_score_df.append(_mean.to_frame().join(_var).join(_count))

    # 2) First score >= 2:
    # First, Calc stats accross each period
    first_score_2_dict = {}
    for column in list(pivot_table.columns):
        first_score_2_dict[column] = pivot_table.index[pivot_table[column] >= 2].min()
    # Second, Calc stats accross each turning
    _turning_score_details_df = pd.DataFrame.from_dict(first_score_2_dict, orient='index', 
                                                       columns= [turnings_keys[i]])
    _mean = pd.Series(_turning_score_details_df.mean(), name='Mean')
    _var = pd.Series(_turning_score_details_df.var(), name='Var')
    _count = pd.Series(_turning_score_details_df.count(), name='Count')
    first_score_2_df = first_score_2_df.append(_mean.to_frame().join(_var).join(_count))

# Join score stats together into a dictionary:
exec_score_dict = {'Average_Score': avg_score_df, 
                   'First_Year_2': first_score_2_df}

# %%
# Means Test to see if the implied distributions are statistically different:

# From Scipy:
# This is a two-sided test for the null hypothesis that two independent samples have identical average 
# (expected) values. Perform Welch’s t-test, which does not assume equal population variance
# From Wiki:
# The p-value is the probability of obtaining test results at least as extreme as the results actually observed,
# under the assumption that the null hypothesis is correct. 
# A very small p-value means that such an extreme observed outcome would be very unlikely 
# under the null hypothesis.

# T-test: 
from scipy.stats import ttest_ind_from_stats

def score_ttest(score_df):  # _score_name
    #pvalue_df = pd.DataFrame()
    #t_statistic_df = pd.DataFrame()
    #for _score in list(score_dict.keys()):
    #    score_df = score_dict[_score]
    #_score = 'Average_Score'
    #score_df = exec_score_dict[_score]
    mean_test = [[0,1],  # First-turning vs. Second-turning
                 [1,2],  # Second-Turning vs. Third-turning
                 [2,3],  # Third-turning vs. Fourth-turning
                 [0,2],  # First-turning vs. Third-turning
                 [0,3],  # First-turning vs. Fourth-turning
                 [1,3]]  # Second-Turning vs. Fourth-turning
    pvalue_dict = {}; t_statistic_dict = {}
    for i, j in mean_test:
        t_statistic, pvalue = ttest_ind_from_stats(mean1=score_df['Mean'][i], std1=np.sqrt(score_df['Var'][i]),
                                                   nobs1=score_df['Count'][i],
                                                   mean2=score_df['Mean'][j], std2=np.sqrt(score_df['Var'][j]),
                                                   nobs2=score_df['Count'][j],
                                                  equal_var=False)
        pvalue_dict.update({"{}_vs_{}".format(score_df.index[i], score_df.index[j]): pvalue})
        t_statistic_dict.update({"{}_vs_{}".format(score_df.index[i], score_df.index[j]): t_statistic})

    pvalue_df = pd.DataFrame.from_dict(pvalue_dict, orient='index', columns=['P_Value'])
    t_statistic_df = pd.DataFrame.from_dict(t_statistic_dict, orient='index', columns=['t_Stat'])
    score_summary_df = pvalue_df.join(t_statistic_df)
    return score_summary_df

# %%
exec_score_dict['Average_Score']
# Out:
#                     Mean       Var  Count
# First_Turning   1.262443  0.223128      3
# Second_Turning  1.304348  0.240076      3
# Third_Turning   1.445383  0.034671      3
# Fourth_Turning  1.294935  0.249180      4

# %%
# Score: Average
score_ttest(exec_score_dict['Average_Score'])
# Out:
#                                    P_Value    t_Stat
# First_Turning_vs_Second_Turning   0.920212 -0.106645
# Second_Turning_vs_Third_Turning   0.677842 -0.466039
# Third_Turning_vs_Fourth_Turning   0.609265  0.553614
# First_Turning_vs_Third_Turning    0.582879 -0.624065
# First_Turning_vs_Fourth_Turning   0.933660 -0.087889
# Second_Turning_vs_Fourth_Turning  0.981160  0.024952

# %%
exec_score_dict['First_Year_2']
# Out:
#                      Mean        Var  Count
# First_Turning   11.000000  32.000000      2
# Second_Turning   7.000000  32.000000      2
# Third_Turning    7.666667  37.333333      3
# Fourth_Turning  11.000000  75.000000      3

# %%
# Score: First Year of a Midlife President (2)

score_ttest(exec_score_dict['First_Year_2'])
# Out:
#                                    P_Value    t_Stat
# First_Turning_vs_Second_Turning   0.552786  0.707107
# Second_Turning_vs_Third_Turning   0.910133 -0.125000
# Third_Turning_vs_Fourth_Turning   0.617940 -0.544735
# First_Turning_vs_Third_Turning    0.585719  0.625000
# First_Turning_vs_Fourth_Turning   1.000000  0.000000
# Second_Turning_vs_Fourth_Turning  0.577051 -0.624695

# %% [markdown]
# #### Political Leadership: Congress - Senate and House combined

# %%
# Convert dates to DateTime format

columns_date_time = ['Birthday', 'Start', 'End']
for index, cols in enumerate(columns_date_time):
    congress_df[cols] = pd.to_datetime(congress_df[cols], infer_datetime_format=True)

# %%
congress_df[congress_df['Birthday'].isna()]
# Out:
#                      Name Birthday  Job      Start        End  \
# 5         Benjamin_Contee      NaT  rep 1789-03-04 1791-03-03
# 11        William_Grayson      NaT  sen 1789-03-04 1791-03-03
# 15            Ralph_Izard      NaT  sen 1789-03-04 1795-03-03
# 25          Michael_Stone      NaT  rep 1789-03-04 1791-03-03
# 30              John_Ashe      NaT  rep 1789-03-04 1791-03-03
# ...                   ...      ...  ...        ...        ...
# 14807      Benjamin_Marsh      NaT  rep 1905-12-04 1907-03-03
# 24667    Edward_Rohrbough      NaT  rep 1943-01-06 1945-01-03
# 24668    Edward_Rohrbough      NaT  rep 1947-01-03 1949-01-03
# 27677  Everett_Burkhalter      NaT  rep 1963-01-09 1965-01-03
# 32115     John_Hutchinson      NaT  rep 1979-01-15 1981-01-03
#
#                      Party
# 5                      NaN
# 11     Anti-Administration
# 15      Pro-Administration
# 25                     NaN
# 30                     NaN
# ...                    ...
# ...

# %%
# Fix missing Birthdays
# John_Hutchinson:  February 4,1935
# Everett_Burkhalter:  Januray 19, 1897
# Edward_Rohrbough:  1874 (month-day unknown)
# Benjamin_Marsh:  1839 (month-day unknown)
# Charles_Hooker:  1825 (month-day unknown)
# Edward_De Nivernais:  February 14, 1866  Source: bioguideretro.congress.gov/
# Robert_Baker:  April 1862  Sournce: Wiki
# John_Cranford:  1862  (month-day unknown)
# Abner_Taylor:  January 19, 1829  Source: Wiki
# Amos_Townsend:  1821  Source: bioguideretro.congress.gov/
# James_Shields:  May 10, 1806  Source: Wiki
# Benjamin_Franklin:  March 1839
# John_Robbins:  1808
# Isaac_Scudder:  1816
# Charles_Lamison:  1826
# Henry_Barry:  1840
# George_Riddle:  1817
# Samuel_Daily: 1823
# William_Sebastian:  
# Paulus_Powell:  1809
# John_Slidell: 1793


birthday_fix_dict = {'John_Hutchinson': '1935-02-04', 
                    'Everett_Burkhalter': '1897-01-19',
                    'Edward_Rohrbough': '1874-01-01',
                    'Benjamin_Marsh': '1839-01-01',
                    'Charles_Hooker': '1825-01-01',
                    'Edward_De Nivernais': '1866-02-14',
                    'Robert_Baker': '1862-04-01',
                    'John_Cranford': '1862-01-01',
                    'Abner_Taylor': '1829-01-19',
                    'Amos_Townsend': '1821-01-01',
                    'James_Shields': '1806-05-10',
                    'Benjamin_Franklin': '1839-03-01',
                    'John_Robbins': '1808-01-01',
                    'Isaac_Scudder': '1816-01-01',
                    'Charles_Lamison': '1826-01-01',
                    'Henry_Barry': '1840-01-01',
                    'George_Riddle': '1817-01-01',
                    'Samuel_Daily': '1823-01-01',
                     'William_Sebastian': '1812-01-01',
                    'Paulus_Powell': '1809-01-01',
                    'John_Slidell': '1793-01-01'}
for index, name in enumerate(birthday_fix_dict.keys()):
    congress_df.loc[congress_df['Name'] == name, 'Birthday'] = pd.to_datetime(birthday_fix_dict[name])

# %%
president_df.tail(20)
# Out:
#                                        Name   Birthday   Job       Party  \
# (1953-01-20, 1957-01-20]  Dwight_Eisenhower 1890-10-14  prez  Republican
# (1957-01-20, 1961-01-20]  Dwight_Eisenhower 1890-10-14  prez  Republican
# (1961-01-20, 1963-11-22]       John_Kennedy 1917-05-29  prez  Democratic
# (1963-11-22, 1965-01-20]     Lyndon_Johnson 1908-08-27  prez  Democratic
# (1965-01-20, 1969-01-20]     Lyndon_Johnson 1908-08-27  prez  Democratic
# (1969-01-20, 1973-01-20]      Richard_Nixon 1913-01-09  prez  Republican
# (1973-01-20, 1974-08-09]      Richard_Nixon 1913-01-09  prez  Republican
# (1974-08-09, 1977-01-20]        Gerald_Ford 1913-07-14  prez  Republican
# (1977-01-20, 1981-01-20]       James_Carter 1924-10-01  prez  Democratic
# (1981-01-20, 1985-01-20]      Ronald_Reagan 1911-02-06  prez  Republican
# (1985-01-20, 1989-01-20]      Ronald_Reagan 1911-02-06  prez  Republican
# (1989-01-20, 1993-01-20]        George_Bush 1924-06-12  prez  Republican
# ...

# %%
congress_df[congress_df['Birthday'].isna()]
# Out:
#                   Name Birthday  Job      Start        End  \
# 5      Benjamin_Contee      NaT  rep 1789-03-04 1791-03-03
# 11     William_Grayson      NaT  sen 1789-03-04 1791-03-03
# 15         Ralph_Izard      NaT  sen 1789-03-04 1795-03-03
# 25       Michael_Stone      NaT  rep 1789-03-04 1791-03-03
# 30           John_Ashe      NaT  rep 1789-03-04 1791-03-03
# ...                ...      ...  ...        ...        ...
# 7559       Albert_Rust      NaT  rep 1859-12-05 1861-03-03
# 7849      George_Shiel      NaT  rep 1861-07-04 1863-03-03
# 7899     Robert_Wilson      NaT  sen 1862-01-01 1863-12-31
# 7974  William_Johnston      NaT  rep 1863-12-07 1865-03-03
# 8348    Thomas_Haughey      NaT  rep 1867-03-04 1869-03-03
#
#                     Party
# 5                     NaN
# 11    Anti-Administration
# 15     Pro-Administration
# 25                    NaN
# 30                    NaN
# ...                   ...
# 7559             Democrat
# 7849             Democrat
# ...

# %%
_missing = congress_df[congress_df['Birthday'].isna()].shape[0] / congress_df.shape[0]
print('Fraction of Congressional Leaders with Birthdays MISSING: {}%; ({}/{})'
      .format(round(_missing * 100, 2),
             round(congress_df[congress_df['Birthday'].isna()].shape[0], 0),
             round(congress_df.shape[0])))
# Out:
# Fraction of Congressional Leaders with Birthdays MISSING: 2.8%; (1165/41620)

# %%
# Merge Generational Info with Executive Leaders:

congress_df['Archetype'] = congress_df['Birthday'].map(generation_df['Archetype'])
congress_df['Generation'] = congress_df['Birthday'].map(generation_df['Generation'])

congress_df = congress_df.set_index(['Start', 'End'])
congress_df.index = pd.IntervalIndex.from_tuples(congress_df.index)

# %%
congress_df
# Out:
#                                       Name   Birthday  Job  \
# (1789-03-04, 1793-03-03]   Richard_Bassett 1745-04-02  sen
# (1789-03-04, 1791-03-03]  Theodorick_Bland 1742-03-21  rep
# (1789-03-04, 1791-03-03]     Aedanus_Burke 1743-06-16  rep
# (1789-03-04, 1791-03-03]    Daniel_Carroll 1730-07-22  rep
# (1789-03-04, 1791-03-03]     George_Clymer 1739-03-16  rep
# ...                                    ...        ...  ...
# (2021-01-03, 2021-01-15]   Cedric_Richmond 1973-09-13  rep
# (2017-01-03, 2021-01-18]     Kamala_Harris 1964-10-20  sen
# (2020-01-06, 2021-01-20]    Kelly_Loeffler 1970-11-27  sen
# (2019-01-03, 2021-01-03]        Ron_Wright 1953-04-08  rep
# (2021-01-03, 2021-02-07]        Ron_Wright 1953-04-08  rep
#
#                                         Party Archetype    Generation
# (1789-03-04, 1793-03-03]  Anti-Administration      Hero    Republican
# (1789-03-04, 1791-03-03]                  NaN      Hero    Republican
# ...

# %%
# Construct Congress Pivot Table:
# (Specify: All-Congress, Senate-only, or House-only)

congress_turnings_dict = {}
congress_pivot_turnings_dict = {}
for index_turnings, name_turnings in enumerate(turnings_keys):
    timeline_turning_df = turnings_dict[name_turnings].copy()
    # Loop through each year in the timeline: Generate Stats on Congress for each year
    summary_congress_df = pd.DataFrame()
    for i in range(timeline_turning_df.shape[0]):
        date_specific_congress = congress_df[congress_df.index.contains(timeline_turning_df['Year'].iloc[i])]
        summary_date_specific_congress = date_specific_congress['Archetype'].value_counts(normalize=True)
        # Test: Skip blank years
        if summary_date_specific_congress.empty:
            continue
        # Congress-specific Score calculation
        # First, test if affected by Civil War Saeculum:
        if timeline_turning_df['Period'].iloc[i] in civil_war_saeclum_list:
            congress_score_df = (civil_war_saeclum_df[[timeline_turning_df['Period'].iloc[i], 'Score_Congress']]
                                 .set_index(timeline_turning_df['Period'].iloc[i]))
        else:
            congress_score_df = archetype_df[[name_turnings, 'Score_Congress']].set_index(name_turnings)
            
        score_specific_congress = summary_date_specific_congress * congress_score_df['Score_Congress']
        summary_date_specific_congress = (summary_date_specific_congress
                                          .append(pd.Series([score_specific_congress.sum()], index=['Score']))
                                          .rename(timeline_turning_df['Year'].iloc[i])
                                          .to_frame()
                                          .T)
        summary_congress_df = summary_congress_df.append(summary_date_specific_congress)
    
    # Now add the summary data 
    timeline_turning_df = timeline_turning_df.set_index('Year').join(summary_congress_df)
    timeline_turning_pivot = timeline_turning_df.pivot(index='Year_Count', columns='Period', values='Score')
    
    congress_turnings_dict[name_turnings] = timeline_turning_df
    congress_pivot_turnings_dict[name_turnings] = timeline_turning_pivot

# %%
# Congress: Comparison of Periods within a Turnings, and accross Turnings 
figure_2, ax = plt.subplots(nrows=4, ncols=1, figsize=(15, 15), sharex=True, sharey=True);
cmap = sns.color_palette("Blues", as_cmap=True) # PuOr, viridis, PRGn, RdBu, icefire
for i in range(4):
    pivot_table = congress_pivot_turnings_dict[turnings_keys[i]]
    pivot_table.plot(ax=ax[i], colormap=cmap, linewidth=5);
    plt.ylabel('Score',fontsize=15);
    plt.xlabel('Years into new Turning/Period',fontsize=15);
    ax[i].set_title(turnings_keys[i], fontsize=20);
print('Generations of U.S. Congress - Comparison Accross Turnings')
plt.show()
# Out:
# Generations of U.S. Congress - Comparison Accross Turnings

# %%
# Plot the average Age of Congressmen/women - it seems to be getting older 

#from dateutil.relativedelta import relativedelta
_index_ages = pd.date_range(start='1789-12-31', end='1999-12-31', freq='Y', name='Year')

ages_list = []
ages_df = pd.DataFrame()
for index, date in enumerate(_index_ages):
    date_specific_congress = congress_df[congress_df.index.contains(date)]
    # date_specific_congress['Age']
    age_series = (date_specific_congress['Birthday']
                  .apply(lambda x: (date - x).days))  #relativedelta(date, x).years
    #_average_age = date_specific_congress['Age'].mean()
    _average_age = age_series.median()
    ages_list.append(round(_average_age / (365.25),0))


ages_df = (ages_df.append(pd.DataFrame(ages_list, index=_index_ages, columns=['Average_Age'])))

# %%
figure_3, ax = plt.subplots(figsize=(10, 5));
ages_df.plot(ax=ax, linewidth=5);
ax.set_title('Average Age of Members of Congress', fontsize=20);

# %%
# Rearange: Group the data by Saeculum:

# turnings_df['Period'].unique()
saeculum_dict = {'Revolutionary_Saeculum': ['Augustan Age of Empire', 'Great Awakening', 'French & Indian Wars', 'American Revolution'],
                'Civil_War_Saeculum': ['Era of Good Feelings', 'Transcendental Awakening', 'Mexican War & Sectionalism', 'Civil War'],
                'Great_Power_Saeculum': ['Reconstruction  & Gilded Age', 'Third Great Awakening', 'World War I & Prohibition', 'Great Depression & World War II'],
                'Millennial_Saeculum': ['American High', 'Consciousness Revolution', 'Long Boom & Culture Wars', 'Global Financial Crisis']}

def regroup_by_saeculum(_dict, turnings_keys, saeculum_dict):
    saeculum_pivot_dict = {'Revolutionary_Saeculum': pd.DataFrame(), 'Civil_War_Saeculum': pd.DataFrame(), 
                         'Great_Power_Saeculum': pd.DataFrame(), 'Millennial_Saeculum': pd.DataFrame()}
    for i in range(4):
        pivot_table = _dict[turnings_keys[i]]
        for saeculum in list(saeculum_dict.keys()):
            for period in saeculum_dict[saeculum]:
                try:
                    _saeculum_df = saeculum_pivot_dict[saeculum]
                    _saeculum_df = _saeculum_df.append(pivot_table[period])
                    saeculum_pivot_dict[saeculum] = _saeculum_df
                except:
                    pass
    return saeculum_pivot_dict

# %%
congress_saeculum_pivot_dict = regroup_by_saeculum(congress_pivot_turnings_dict, turnings_keys, saeculum_dict)
#saeculum_pivot_dict['Great_Power']

# %%
# Plot by Saeculum:

saeculum_keys = list(saeculum_dict.keys())

figure_4, ax = plt.subplots(nrows=4, ncols=1, figsize=(15, 15), sharex=True, sharey=True);
cmap = sns.color_palette("Blues", as_cmap=True) # PuOr, viridis, PRGn, RdBu, icefire
for i in range(4):
    pivot_table = congress_saeculum_pivot_dict[saeculum_keys[i]].T
    pivot_table.plot(ax=ax[i], colormap=cmap, linewidth=5);
    plt.ylabel('Score',fontsize=15);
    plt.xlabel('Years into new Turning/Period',fontsize=15);
    ax[i].set_title(saeculum_keys[i], fontsize=20);
print('Generations of U.S. Congress - Comparison Accross Saeculums')
plt.show()
# Out:
# Generations of U.S. Congress - Comparison Accross Saeculums

# %%
# Scoring: Congress

def score_statistics(pivot_turnings_dict, turnings_keys, key_level):
    
    avg_score_df = pd.DataFrame()
    first_score_percent_df = pd.DataFrame()
    for i in range(4):  # Loop through Turnings 
        pivot_table = pivot_turnings_dict[turnings_keys[i]]

        # 1) Values:
        _turning_score_details_df = pd.DataFrame(pivot_table.mean(), columns=[turnings_keys[i]])
        _mean = pd.Series(_turning_score_details_df.mean(), name='Mean')
        _var = pd.Series(_turning_score_details_df.var(), name='Var')
        _count = pd.Series(_turning_score_details_df.count(), name='Count')
        avg_score_df = avg_score_df.append(_mean.to_frame().join(_var).join(_count))

        # 2) First score >= 2:
        # First, Calc stats accross each period
        first_score_dict = {}
        for column in list(pivot_table.columns):
            first_score_dict[column] = pivot_table.index[pivot_table[column] >= key_level].min()
        # Second, Calc stats accross each turning
        _turning_score_details_df = pd.DataFrame.from_dict(first_score_dict, orient='index', 
                                                           columns= [turnings_keys[i]])
        _mean = pd.Series(_turning_score_details_df.mean(), name='Mean')
        _var = pd.Series(_turning_score_details_df.var(), name='Var')
        _count = pd.Series(_turning_score_details_df.count(), name='Count')
        first_score_percent_df = first_score_percent_df.append(_mean.to_frame().join(_var).join(_count))

    # Join score stats together into a dictionary:
    summary_score_dict = {'Average_Score': avg_score_df, 'First_Year_Key_Level': first_score_percent_df}
    return summary_score_dict

# %%
# Test Congress with Civil War dropped from Fourth Turning
adj_congress_pivot_turnings_dict = congress_pivot_turnings_dict.copy()
adj_congress_pivot_turnings_dict['Fourth_Turning'] = (congress_pivot_turnings_dict['Fourth_Turning']
                                                      .drop('Civil War', axis=1))
congress_score_dict = score_statistics(adj_congress_pivot_turnings_dict, turnings_keys, key_level=0.5)

# %%
congress_score_dict['Average_Score']
# Out:
#                     Mean       Var  Count
# First_Turning   0.722726  0.049199      3
# Second_Turning  0.674711  0.075760      3
# Third_Turning   0.709963  0.054601      3
# Fourth_Turning  0.602648  0.122433      3

# %%
score_ttest(congress_score_dict['Average_Score'])
# Out:
#                                    P_Value    t_Stat
# First_Turning_vs_Second_Turning   0.826053  0.235264
# Second_Turning_vs_Third_Turning   0.874125 -0.169108
# Third_Turning_vs_Fourth_Turning   0.684642  0.441765
# First_Turning_vs_Third_Turning    0.948595  0.068618
# First_Turning_vs_Fourth_Turning   0.646521  0.502026
# Second_Turning_vs_Fourth_Turning  0.793827  0.280370

# %%
# Score: Simple Majority:

congress_score_dict['First_Year_Key_Level']
# Out:
#                      Mean        Var  Count
# First_Turning    4.333333  20.333333      3
# Second_Turning   6.666667  42.333333      3
# Third_Turning    4.333333  56.333333      3
# Fourth_Turning  12.000000  32.000000      2

# %%
score_ttest(congress_score_dict['First_Year_Key_Level'])
# Out:
#                                    P_Value    t_Stat
# First_Turning_vs_Second_Turning   0.639679 -0.510527
# Second_Turning_vs_Third_Turning   0.705333  0.406867
# Third_Turning_vs_Fourth_Turning   0.290325 -1.300037
# First_Turning_vs_Third_Turning    1.000000  0.000000
# First_Turning_vs_Fourth_Turning   0.258528 -1.606390
# Second_Turning_vs_Fourth_Turning  0.414023 -0.971931

# %% [markdown]
# #### Economic Data: GDP-per-Capita

# %%
# GDP-per-Capita:

Maddison_Project_Database_2020_url = 'https://www.rug.nl/ggdc/historicaldevelopment/maddison/data/mpd2020.xlsx'
resp = requests.get(Maddison_Project_Database_2020_url)
local_path = home_path / 'Maddison_Project_Database_2020'
with open(local_path, 'wb') as output:
    output.write(resp.content)

gdp_per_cap_hist_raw_data_df = pd.read_excel(local_path, sheet_name='Full data', header=0) 
#dtype= {'gdppc': np.int32, 'pop': np.int32})

#gdp_per_cap_hist_raw_data.dtypes
#countrycode     object
#country         object
#year             int64
#gdppc          float64
#pop            float64

# %%
us_gdp_per_cap_hist_df = gdp_per_cap_hist_raw_data_df[gdp_per_cap_hist_raw_data_df['countrycode'] == 'USA']

gdp_per_cap_columns_dict = {'countrycode': 'Country_Code', 'country': 'Country', 'year': 'Year', 
                            'gdppc': 'GDP_per_Capita', 'pop': 'Population'}
us_gdp_per_cap_hist_df = us_gdp_per_cap_hist_df.rename(columns=gdp_per_cap_columns_dict)

_years = pd.to_datetime(us_gdp_per_cap_hist_df.pop('Year'), errors='coerce', format='%Y')
us_gdp_per_cap_hist_df.index = _years + pd.tseries.offsets.YearEnd()
us_gdp_per_cap_hist_df = us_gdp_per_cap_hist_df.drop(index=pd.to_datetime(np.nan))

us_gdp_per_cap_hist_df[['GDP_per_Capita', 'Population']] = (us_gdp_per_cap_hist_df[['GDP_per_Capita', 'Population']]
                                                            .apply(lambda x: round(x,0)))

# %%
us_gdp_per_cap_hist_df['Population'].dropna()
# Out:
# Year
# 1700-12-31      1000.0
# 1820-12-31      9981.0
# 1821-12-31     10299.0
# 1822-12-31     10626.0
# 1823-12-31     10951.0
#                 ...
# 2014-12-31    319036.0
# 2015-12-31    321397.0
# 2016-12-31    323730.0
# 2017-12-31    325810.0
# 2018-12-31    327835.0
# Name: Population, Length: 200, dtype: float64

# %%
# American GDP-per-Capita: Log Plot

figure_6, ax = plt.subplots(figsize=(10,5))
log_gdp_per_cap_hist_series = (us_gdp_per_cap_hist_df['GDP_per_Capita']
                                            .dropna()
                                            .apply(lambda x: np.log(x)))
sns.lineplot(data=log_gdp_per_cap_hist_series.to_frame(), x='Year', y='GDP_per_Capita', ax=ax,
            linewidth=5);
ax.set_title('History of American GDP-per-Capita (log Scale)', fontsize=20);

# %%
# American Population Growth: Log Plot

figure_600, ax = plt.subplots(figsize=(10,5))
log_population_series = (us_gdp_per_cap_hist_df['Population']
                         .dropna()
                         .apply(lambda x: np.log(x)))
sns.lineplot(data=log_population_series.dropna().to_frame(), x='Year', y='Population', 
             ax=ax, linewidth=5);
ax.set_title('History of American Population Growth', fontsize=20);

# %%
per_capita_dict = turnings_dict.copy()
per_capita_pivot_dict = {}
pop_growth_pivot_dict = {}

for index_turnings, name_turnings in enumerate(turnings_keys):
    per_capita_dict[name_turnings]['GDP_per_Capita'] = (per_capita_dict[name_turnings]['Year']
                                                           .map(us_gdp_per_cap_hist_df['GDP_per_Capita']))
    per_capita_dict[name_turnings]['Population'] = (per_capita_dict[name_turnings]['Year']
                                                       .map(us_gdp_per_cap_hist_df['Population']))

    per_capita_pivot = (per_capita_dict[name_turnings]
                        .pivot(index='Year_Count', columns='Period', values='GDP_per_Capita'))
    pop_growth_pivot = (per_capita_dict[name_turnings]
                        .pivot(index='Year_Count', columns='Period', values='Population'))

    # Try: Replace 1.0 with NaN
    for columns in list(per_capita_pivot.columns):
        _indexer = per_capita_pivot[columns].notna().replace(to_replace=False, value=np.nan)
        per_capita_pivot[columns] = per_capita_pivot[columns].pct_change().fillna(0).add(1).cumprod()
        per_capita_pivot[columns] = per_capita_pivot[columns] * _indexer
    for columns in list(pop_growth_pivot.columns):
        _indexer = pop_growth_pivot[columns].notna().replace(to_replace=False, value=np.nan)
        pop_growth_pivot[columns] = pop_growth_pivot[columns].pct_change().fillna(0).add(1).cumprod()
        #per_capita_pivot[columns] = per_capita_pivot[columns].replace(1.0000, np.nan)
        pop_growth_pivot[columns] = pop_growth_pivot[columns] * _indexer
        
    per_capita_pivot_dict[name_turnings] = per_capita_pivot
    pop_growth_pivot_dict[name_turnings] = pop_growth_pivot

# %%
figure_7, ax = plt.subplots(nrows=4, ncols=1, figsize=(15, 15), sharex=True, sharey=True);
cmap = sns.color_palette("Blues", as_cmap=True) # PuOr, viridis, PRGn, RdBu, icefire
for i in range(4):
    pivot_table = per_capita_pivot_dict[turnings_keys[i]]
    pivot_table.plot(ax=ax[i], colormap=cmap, linewidth=5);
    plt.ylabel('Cumulative Growth',fontsize=15);
    plt.xlabel('Years into new Turning/Period',fontsize=15);
    ax[i].set_title(turnings_keys[i], fontsize=20);
print('GDP-per-Capita Growth - Comparison Accross Turnings')
plt.show()
# Out:
# GDP-per-Capita Growth - Comparison Accross Turnings

# %%
# Scoring Statistics: GDP-per-Capita

score_gdp_per_cap_df = pd.DataFrame()
for i in range(4):
    _turning_score_details_df = per_capita_pivot_dict[turnings_keys[i]].iloc[10].rename(turnings_keys[i])
    _mean = pd.Series(_turning_score_details_df.mean(), name='Mean', index=[turnings_keys[i]])
    _var = pd.Series(_turning_score_details_df.var(), name='Var', index=[turnings_keys[i]])
    _count = pd.Series(_turning_score_details_df.count(), name='Count', index=[turnings_keys[i]])
    score_gdp_per_cap_df = score_gdp_per_cap_df.append(_mean.to_frame().join(_var).join(_count))

# %%
score_gdp_per_cap_df
# Out:
#                     Mean       Var  Count
# First_Turning   1.097184  0.006160      3
# Second_Turning  1.184269  0.013030      3
# Third_Turning   1.202791  0.001107      3
# Fourth_Turning  1.017562  0.013799      2

# %%
score_ttest(score_gdp_per_cap_df)
# Out:
#                                    P_Value    t_Stat
# First_Turning_vs_Second_Turning   0.344626 -1.088870
# Second_Turning_vs_Third_Turning   0.809298 -0.269816
# Third_Turning_vs_Fourth_Turning   0.254845  2.172638
# First_Turning_vs_Third_Turning    0.131286 -2.145769
# First_Turning_vs_Fourth_Turning   0.506364  0.841508
# Second_Turning_vs_Fourth_Turning  0.244507  1.572245

# %%
# GDP-per-Capita Growth: Group and Plot by Saeculum

saeculum_per_capita_pivot_dict = regroup_by_saeculum(per_capita_pivot_dict, turnings_keys, saeculum_dict)

saeculum_keys = list(saeculum_dict.keys())

figure_8, ax = plt.subplots(nrows=4, ncols=1, figsize=(15, 15), sharex=True, sharey=True);
cmap = sns.color_palette("Blues", as_cmap=True) # PuOr, viridis, PRGn, RdBu, icefire
for i in range(4):
    pivot_table = saeculum_per_capita_pivot_dict[saeculum_keys[i]].T
    pivot_table.plot(ax=ax[i], colormap=cmap, linewidth=5);
    plt.ylabel('Cumulative Growth',fontsize=15);
    plt.xlabel('Years into new Turning/Period',fontsize=15);
    ax[i].set_title(saeculum_keys[i], fontsize=20);
print('GDP-per-Capita Growth - Comparison Accross Saeculums')
plt.show()
# Out:
# GDP-per-Capita Growth - Comparison Accross Saeculums

# %%
# Calculate Stats: Compare at the 10-year mark (roughly half way)

# Scoring Statistics: GDP-per-Capita

saeculum_score_gdp_per_cap_df = pd.DataFrame()
for i in range(4):
    _turning_score_details_df = saeculum_per_capita_pivot_dict[saeculum_keys[i]].T.iloc[10].rename(saeculum_keys[i])
    _mean = pd.Series(_turning_score_details_df.mean(), name='Mean', index=[saeculum_keys[i]])
    _var = pd.Series(_turning_score_details_df.var(), name='Var', index=[saeculum_keys[i]])
    _count = pd.Series(_turning_score_details_df.count(), name='Count', index=[saeculum_keys[i]])
    saeculum_score_gdp_per_cap_df = saeculum_score_gdp_per_cap_df.append(_mean.to_frame().join(_var).join(_count))

# %%
saeculum_score_gdp_per_cap_df
# Out:
#                             Mean       Var  Count
# Revolutionary_Saeculum       NaN       NaN      0
# Civil_War_Saeculum      1.148882  0.013358      3
# Great_Power_Saeculum    1.066487  0.009542      4
# Millennial_Saeculum     1.193815  0.006267      4

# %%
score_ttest(saeculum_score_gdp_per_cap_df)
# Out:
#                                                  P_Value    t_Stat
# Revolutionary_Saeculum_vs_Civil_War_Saeculum         NaN       NaN
# Civil_War_Saeculum_vs_Great_Power_Saeculum      0.375987  0.996396
# Great_Power_Saeculum_vs_Millennial_Saeculum     0.091272 -2.025313
# Revolutionary_Saeculum_vs_Great_Power_Saeculum       NaN       NaN
# Revolutionary_Saeculum_vs_Millennial_Saeculum        NaN       NaN
# Civil_War_Saeculum_vs_Millennial_Saeculum       0.598895 -0.579144

# %%
# Population Growth: 

figure_9, ax = plt.subplots(nrows=4, ncols=1, figsize=(15, 15), sharex=True, sharey=True);
cmap = sns.color_palette("Blues", as_cmap=True) # PuOr, viridis, PRGn, RdBu, icefire
for i in range(4):
    pivot_table = pop_growth_pivot_dict[turnings_keys[i]]
    pivot_table.plot(ax=ax[i], colormap=cmap, linewidth=5);
    plt.ylabel('Cumulative Growth',fontsize=15);
    plt.xlabel('Years into new Turning/Period',fontsize=15);
    ax[i].set_title(turnings_keys[i], fontsize=20);
#ax[0].set_title('Generation of U.S. Vice Presidents - Comparison Accross Turnings', fontsize=20);
print('Population Growth - Comparison Accross Turnings')
#print(f'Scoring: {score_ylabel}')
plt.show()
# Out:
# Population Growth - Comparison Accross Turnings

# %%
score_pop_growth_df = pd.DataFrame()
for i in range(4):
    _turning_score_details_df = pop_growth_pivot_dict[turnings_keys[i]].iloc[10].rename(turnings_keys[i])
    _mean = pd.Series(_turning_score_details_df.mean(), name='Mean', index=[turnings_keys[i]])
    _var = pd.Series(_turning_score_details_df.var(), name='Var', index=[turnings_keys[i]])
    _count = pd.Series(_turning_score_details_df.count(), name='Count', index=[turnings_keys[i]])
    score_pop_growth_df = score_pop_growth_df.append(_mean.to_frame().join(_var).join(_count))

# %%
score_pop_growth_df
# Out:
#                     Mean           Var  Count
# First_Turning   1.222842  2.162432e-03      2
# Second_Turning  1.220928  1.107144e-02      3
# Third_Turning   1.215225  1.492748e-02      3
# Fourth_Turning  1.075953  1.124117e-08      2

# %%
score_ttest(score_pop_growth_df)
# Out:
#                                    P_Value    t_Stat
# First_Turning_vs_Second_Turning   0.979718  0.027708
# Second_Turning_vs_Third_Turning   0.954149  0.061264
# Third_Turning_vs_Fourth_Turning   0.187034  1.974387
# First_Turning_vs_Third_Turning    0.928819  0.097874
# First_Turning_vs_Fourth_Turning   0.140197  4.467186
# Second_Turning_vs_Fourth_Turning  0.139711  2.386456

# %%
# Congressional Budget Office (CBO): Historical Data on Federal Debt Held by the Public
# CBO: Federal Debt: A PrimerMarch 12, 2020
# Source: https://www.cbo.gov/publication/56165

debt_history_url = 'https://www.cbo.gov/system/files/2020-03/56165-CBO-data-underlying-figures.xlsx'

resp = requests.get(debt_history_url)
local_path = home_path / 'CBO_Federal_Debt_1790_2010.xls'
with open(local_path, 'wb') as output:
    output.write(resp.content)

debt_history_df = pd.read_excel(debt_history_url, sheet_name='Summary Figure 1', 
                                  skiprows=list(np.linspace(0,9,9, dtype=int)),
                                  usecols=list(np.linspace(0,1,2, dtype=int)), 
                                  nrows=240, header=None, parse_dates=True, index_col=0) 

debt_history_df = (debt_history_df.rename(columns={debt_history_df.columns[0]: 'Debt_Pct_GDP'})
                   .apply(lambda x: round(x,1)))

debt_history_df['Year'] = debt_history_df.index + pd.tseries.offsets.YearEnd()
debt_history_df = debt_history_df.set_index('Year', drop=True)

# %%
# Drop CBO Future Projections: 
projected_index = debt_history_df.index[-11:]

debt_history_df = debt_history_df.drop(index=projected_index)

# %%
figure_100, ax = plt.subplots(figsize=(10,5))
sns.lineplot(data=debt_history_df, x='Year', y='Debt_Pct_GDP', ax=ax, linewidth=5);
ax.set_title('History of U.S. Federal Debt-to-GDP', fontsize=20);

# %%
# Construct Pivot Table: through a loop

debt_dict = turnings_dict.copy()
debt_pivot_dict = {}

for index_turnings, name_turnings in enumerate(turnings_keys):
    debt_dict[name_turnings]['Debt_Pct_GDP'] = (debt_dict[name_turnings]['Year']
                                                .map(debt_history_df['Debt_Pct_GDP']))

    debt_pivot = (debt_dict[name_turnings].pivot(index='Year_Count', columns='Period', values='Debt_Pct_GDP'))

    for columns in list(debt_pivot.columns):
        _indexer = debt_pivot[columns].notna().replace(to_replace=False, value=np.nan)
        debt_pivot[columns] = debt_pivot[columns].diff().fillna(0).add(1).cumsum()
        debt_pivot[columns] = debt_pivot[columns] * _indexer
        
    debt_pivot_dict[name_turnings] = debt_pivot

# %%
figure_10, ax = plt.subplots(nrows=4, ncols=1, figsize=(15, 15), sharex=True, sharey=True);
cmap = sns.color_palette("Blues", as_cmap=True) # PuOr, viridis, PRGn, RdBu, icefire
for i in range(4):
    pivot_table = debt_pivot_dict[turnings_keys[i]]
    pivot_table.plot(ax=ax[i], colormap=cmap, linewidth=5);
    plt.ylabel('Cumulative Growth in Debt-to-GDP (%)',fontsize=15);
    plt.xlabel('Years into new Turning/Period',fontsize=15);
    ax[i].set_title(turnings_keys[i], fontsize=20);
print('Debt-to-GDP Growth - Comparison Accross Turnings')
plt.show()
# Out:
# Debt-to-GDP Growth - Comparison Accross Turnings

# %%
debt_pivot_dict[turnings_keys[1]].ffill().iloc[-1].rename()
# Out:
# Period
# Consciousness Revolution    15.3
# Third Great Awakening       14.9
# Transcendental Awakening    15.9
# dtype: float64

# %%
end_debt_df = pd.DataFrame()
for i in range(4):
    _last = debt_pivot_dict[turnings_keys[i]].ffill().iloc[-1].rename('Growth in Federal Debt (% of GDP)').to_frame()
    end_debt_df = end_debt_df.append(_last)

# %%
end_debt_df.sort_values(by='Growth in Federal Debt (% of GDP)', ascending=True, inplace=True)

figure_1000, ax = plt.subplots(figsize=(10, 5));
sns.barplot(data=end_debt_df.reset_index(), y='Period', x='Growth in Federal Debt (% of GDP)', 
            orient='h', palette='viridis', ax=ax);
ax.set_title('Federal Debt-to-GDP Growth', fontsize=20);
#end_debt_df

# %%
# Scoring Statistics: Debt-to-GDP

score_debt_df = pd.DataFrame()
for i in range(4):
    _turning_score_details_df = debt_pivot_dict[turnings_keys[i]].iloc[10].rename(turnings_keys[i])
    _mean = pd.Series(_turning_score_details_df.mean(), name='Mean', index=[turnings_keys[i]])
    _var = pd.Series(_turning_score_details_df.var(), name='Var', index=[turnings_keys[i]])
    _count = pd.Series(_turning_score_details_df.count(), name='Count', index=[turnings_keys[i]])
    score_debt_df = score_debt_df.append(_mean.to_frame().join(_var).join(_count))

# %%
score_debt_df
# Out:
#                      Mean         Var  Count
# First_Turning  -12.766667  750.923333      3
# Second_Turning   1.966667   35.763333      3
# Third_Turning   24.566667  167.373333      3
# Fourth_Turning  43.800000   54.080000      2

# %%
score_ttest(score_debt_df)
# Out:
#                                    P_Value    t_Stat
# First_Turning_vs_Second_Turning   0.451694 -0.909831
# Second_Turning_vs_Third_Turning   0.076093 -2.746470
# Third_Turning_vs_Fourth_Turning   0.124996 -2.113284
# First_Turning_vs_Third_Turning    0.127325 -2.133860
# First_Turning_vs_Fourth_Turning   0.059290 -3.396630
# Second_Turning_vs_Fourth_Turning  0.024789 -6.702037

# %%
# Circle Back to Political Leaders - Count by Archetype 

presidents_by_generation_df = (generation_df[['Generation', 'Archetype', 'Start', 'End']]
                               .join(president_df[['Generation','Name']]
                                     .groupby(by='Generation').count()
                                     .rename(columns={'Name': 'Terms_Count'}), 
                                     on='Generation')).fillna(0)

# %%
presidents_by_generation_df
# Out:
#                               Generation Archetype Start   End  Terms_Count
# [1701-01-01, 1724-01-01)       Awakening   Prophet  1701  1723          0.0
# [1724-01-01, 1742-01-01)         Liberty     Nomad  1724  1741          3.0
# [1742-01-01, 1767-01-01)      Republican      Hero  1742  1766          6.0
# [1767-01-01, 1792-01-01)      Compromise    Artist  1767  1791          8.0
# [1792-01-01, 1822-01-01)  Transcendental   Prophet  1792  1821          6.0
# [1822-01-01, 1843-01-01)          Gilded     Nomad  1822  1842          8.0
# [1843-01-01, 1860-01-01)     Progressive    Artist  1843  1859          7.0
# [1860-01-01, 1883-01-01)      Missionary   Prophet  1860  1882          8.0
# [1883-01-01, 1901-01-01)            Lost     Nomad  1883  1900          4.0
# [1901-01-01, 1925-01-01)            G.I.      Hero  1901  1924         10.0
# [1925-01-01, 1943-01-01)          Silent    Artist  1925  1942          1.0
# ...

# %%
# Adjust for the Biden presidency, 
# and remove Generations with less information (Awakeining, Gen X, Millenials, Homelanders)
add_biden_df = presidents_by_generation_df.reset_index().set_index('Generation') 
add_biden_df.at['Boom', 'Terms_Count'] = add_biden_df.at['Boom', 'Terms_Count'] + 1

# %%
figure_11, ax = plt.subplots(figsize=(10, 5));
sns.barplot(data=add_biden_df.reset_index(), x='Terms_Count', y='Generation', orient='h', 
           palette='viridis', ax=ax); # PuOr, viridis, PRGn, RdBu, icefire
ax.set_title('Presidential Elections Won by each Generation', fontsize=20);

# %%
figure_12, ax = plt.subplots(figsize=(10, 5));
sns.boxplot(data=add_biden_df[1:-3].reset_index(), x='Archetype', y='Terms_Count', orient='v', 
           palette='viridis', ax=ax); # PuOr, viridis, PRGn, RdBu, icefire
ax.set_title('Presidential Terms by each Generational Archetype', fontsize=20);

# %%
# Stats: Generational Presidents 

add_biden_df = add_biden_df[1:-3].reset_index().set_index('index')

_mean = add_biden_df[['Archetype','Terms_Count']].groupby(by='Archetype').mean()
_var = add_biden_df[['Archetype','Terms_Count']].groupby(by='Archetype').var()
_count = add_biden_df[['Archetype','Terms_Count']].groupby(by='Archetype').count()

_mean = _mean.rename(columns={'Terms_Count': 'Mean'})
_var = _var.rename(columns={'Terms_Count': 'Var'})
_count = _count.rename(columns={'Terms_Count': 'Count'})

stats_generational_presidents_df = _mean.join(_var).join(_count)

# %%
stats_generational_presidents_df
# Out:
#                Mean        Var  Count
# Archetype
# Artist     5.333333  14.333333      3
# Hero       8.000000   8.000000      2
# Nomad      5.000000   7.000000      3
# Prophet    6.666667   1.333333      3

# %%
score_ttest(stats_generational_presidents_df)
# Out:
#                     P_Value    t_Stat
# Artist_vs_Hero     0.438452 -0.900070
# Hero_vs_Nomad      0.348517  1.192079
# Nomad_vs_Prophet   0.397391 -1.000000
# Artist_vs_Nomad    0.907227  0.125000
# Artist_vs_Prophet  0.610381 -0.583460
# Hero_vs_Prophet    0.624358  0.632456

# %%
# US Income Inequality: 1850, 1860, 1870, 1913 - present
# Source:  https://wid.world/
# Source: 'http://gpih.ucdavis.edu/tables.htm'

# Data download and formatting are done in a seperate notebook, with the output being the below CSV file

# %%
ex1774_income_inequality_df = pd.read_csv(home_path / 'Income_Inequality_WID_GPIH.csv', 
                                          index_col=0, parse_dates=True)

# %%
# DELETE:
# ex1774_income_inequality_df.index = ex1774_income_inequality_df.index.rename('Year')

# %%
figure, ax = plt.subplots(figsize=(10, 5));
ex1774_income_inequality_df.plot(figsize=(15,5), ax=ax);
ax.set_title('US Income Distribution: 1850 - Present', fontsize=20);
ax.set_ylabel('% of Total US Income', fontsize=20);

# %%
# The 40%-80%, or Next-40%, seems to contain the most information than any other individual series alone
figure, ax = plt.subplots(figsize=(10, 5));
ex1774_income_inequality_df['Top 10%'].to_frame().plot(figsize=(15,5), ax=ax, color=u'k');  # 'Next 40%'
ax.set_title('US Income for Top Decile (10%) Group: 1850 - Present', fontsize=20);
ax.set_ylabel('% of Total US Income', fontsize=20);

# %%
# Construct Pivot Table: through a loop
inequality_dict = turnings_dict.copy()
inequality_pivot_dict = {}
for index_turnings, name_turnings in enumerate(turnings_keys):
    inequality_dict[name_turnings]['Income_Share_10_Percentile'] = (inequality_dict[name_turnings]['Year']
                                                .map(ex1774_income_inequality_df['Top 10%']))
    inequality_pivot = (inequality_dict[name_turnings]
                        .pivot(index='Year_Count', columns='Period', values='Income_Share_10_Percentile'))
    inequality_pivot_dict[name_turnings] = inequality_pivot

# %%
figure_15, ax = plt.subplots(nrows=4, ncols=1, figsize=(15, 15), sharex=True, sharey=True);
cmap = sns.color_palette("Blues", as_cmap=True) # PuOr, viridis, PRGn, RdBu, icefire
for i in range(4):
    pivot_table = inequality_pivot_dict[turnings_keys[i]]
    pivot_table.plot(ax=ax[i], colormap=cmap, linewidth=5);
    plt.ylabel('Cumulative Change in US Middleclass Income (%)',fontsize=15);
    plt.xlabel('Years into new Turning/Period',fontsize=15);
    ax[i].set_title(turnings_keys[i], fontsize=20);
print('US Income for Top Decile (10%) Group - Comparison Accross Turnings')
plt.show()
# Out:
# US Income for 40-80 Percentile Group - Comparison Accross Turnings

# %%
# Stat: Calculate the change for each period in each turning (start to finish)

score_inequality_df = pd.DataFrame()
for i in range(4):
    _turning_score_details_df = (inequality_pivot_dict[turnings_keys[i]].diff().cumsum().ffill().iloc[-1]
                                 .rename(turnings_keys[i]))
    try:
        _turning_score_details_df = _turning_score_details_df.drop(labels=['Global Financial Crisis'])
    except:
        pass
    _mean = pd.Series(_turning_score_details_df.mean(), name='Mean', index=[turnings_keys[i]])
    _var = pd.Series(_turning_score_details_df.var(), name='Var', index=[turnings_keys[i]])
    _count = pd.Series(_turning_score_details_df.count(), name='Count', index=[turnings_keys[i]])
    score_inequality_df = score_inequality_df.append(_mean.to_frame().join(_var).join(_count))

# %%
score_inequality_df
# Out:
#                     Mean        Var  Count
# First_Turning   1.153942   0.487959      2
# Second_Turning  0.257707   2.279997      2
# Third_Turning   4.782306  11.006315      3
# Fourth_Turning -4.273026  49.143173      2

# %%
score_ttest(score_inequality_df)
# Out:
#                                    P_Value    t_Stat
# First_Turning_vs_Second_Turning   0.552946  0.761828
# Second_Turning_vs_Third_Turning   0.134868 -2.063303
# Third_Turning_vs_Fourth_Turning   0.291526  1.703999
# First_Turning_vs_Third_Turning    0.193534 -1.834298
# First_Turning_vs_Fourth_Turning   0.469994  1.089420
# Second_Turning_vs_Fourth_Turning  0.525335  0.893520

# %% [markdown]
# # Conclusion
#
# Let's look at a few aspects of American history, as seen through the lens of generations and the seasons of history.
#
# ### American Political Leadership: The President
#
# Leadership is an important part of the story for any organization. The same goes for America and its political leadership. Looking at the office of the U.S. President, through the lens of generations, it's notable that the G.I. generation has held more terms of President then any other generation. After returning from World War II in their Young Adult phase, the G.I. generation came back to build America's institutions in their Midlife (ages 42 - 62) and Elderhood (ages 63 - 83). They seemed to acquire these terms from the generation directly before them - the Lost generation - and the generation directly after them – the Silent generation. If there was an analogous phenomenon in history, it looks like it would be the Republican generation – also a generation of the “Hero” archetype, who came of age during the American Revolution.

# %%
figure_11

# %% [markdown]
# Reconfiguring this data into William Strauss and Neil Howe's theory of the four "Archetypes" of a Generation - Nomad, Hero, Artist, and Prophet - shows the frequency with which each of these generational Archetypes has been elected to the office of the President. Overall, the Hero generations has, on average, been elected to 8 terms, the most of any archetype. This is followed closely by the Prophet generations at ~7 terms, while the Nomad and Artist generations have, on average, served on average only 5 terms. This data fits very well with the narrative of the Hero and Prophet generations leading America through the crucial Awakening and Crisis periods, which are defined as evolutions in our culture/shared-values and civic/social-structures, respectively.

# %%
figure_12

# %% [markdown]
# However, the results are not statistically significant using a two-sample t-test to compare the averages across each combination of archetypes. Statistical significance, at the common 90% confidence-level or above, is a challenge throughout this analysis given the small sample sizes. While the analysis spans across the entire, 200+ year sweep of U.S. history as an independent nation, each generation and turning spans approximately 20-years, and there are four generational archetypes and four types of turnings (totaling ~80-years), making the sample-size only three samples for each.

# %%
score_ttest(stats_generational_presidents_df)
# Out:
#                     P_Value    t_Stat
# Artist_vs_Hero     0.438452 -0.900070
# Hero_vs_Nomad      0.348517  1.192079
# Nomad_vs_Prophet   0.397391 -1.000000
# Artist_vs_Nomad    0.907227  0.125000
# Artist_vs_Prophet  0.610381 -0.583460
# Hero_vs_Prophet    0.624358  0.632456

# %%
generation_df.drop(columns=['Start', 'End', 'Start_dt'])
# Out:
#                               Generation Birth Years                      Man  \
# [1701-01-01, 1724-01-01)       Awakening   1701–1723         Jonathan Edwards
# [1724-01-01, 1742-01-01)         Liberty   1724–1741        George Washington
# [1742-01-01, 1767-01-01)      Republican   1742–1766         Thomas Jefferson
# [1767-01-01, 1792-01-01)      Compromise   1767–1791           Andrew Jackson
# [1792-01-01, 1822-01-01)  Transcendental   1792–1821          Abraham Lincoln
# [1822-01-01, 1843-01-01)          Gilded   1822–1842            Ulysses Grant
# [1843-01-01, 1860-01-01)     Progressive   1843–1859           Woodrow Wilson
# [1860-01-01, 1883-01-01)      Missionary   1860–1882       Franklin Roosevelt
# [1883-01-01, 1901-01-01)            Lost   1883–1900             Harry Truman
# [1901-01-01, 1925-01-01)            G.I.   1901–1924             John Kennedy
# [1925-01-01, 1943-01-01)          Silent   1925–1942  Martin Luther King, Jr.
# ...

# %% [markdown]
# That was through the lense of Generations. Let's now turn to Turnings - or the seasons of history. Each Turning coincides - starts and stops - with each generation moving from one phase of life to the next phase of life (Childhood through Elderhood). For example, as the Millenial generation begins to move from the Young Adult phase to Midlife, and Generation X into Elderhood, it marks the beggining of a new season of history. American political leadership, corporate American leadership, and the leadership of all of our social institutions will begin to transition to the next generation - who exhibit distinct and different behaviors and values than the generation before them.

# %%
turnings_df.drop(columns=['Start_dt', 'End_dt'])
# Out:
#            Turning                           Period       Saeculum Start   End
# 13  Fourth_Turning              American Revolution  Revolutionary  1773  1794
# 14   First_Turning             Era of Good Feelings      Civil War  1794  1822
# 15  Second_Turning         Transcendental Awakening      Civil War  1822  1844
# 16   Third_Turning       Mexican War & Sectionalism      Civil War  1844  1860
# 17  Fourth_Turning                        Civil War      Civil War  1860  1865
# 18   First_Turning     Reconstruction  & Gilded Age    Great Power  1865  1886
# 19  Second_Turning            Third Great Awakening    Great Power  1886  1908
# 20   Third_Turning        World War I & Prohibition    Great Power  1908  1929
# 21  Fourth_Turning  Great Depression & World War II    Great Power  1929  1946
# 22   First_Turning                    American High     Millennial  1946  1964
# 23  Second_Turning         Consciousness Revolution     Millennial  1964  1984
# ...

# %% [markdown]
# The chart below shows the progression of Presidential leadership from one generation to the next, throughout American history.
# Each period (for example the post-Civil War “Reconstruction and Gilded Age” of 1865 - 1886) is represented by a line, and grouped with the other periods that belong in the same "Turnings" or season of history. For example, the Civil War belongs in the Fourth Turning or "Crisis" period, along with the Great Depression and World War II of 1929 - 1946, and the Millennial Crisis period today (2008 - 2029?). This facilitates analysis both within Turnings and across Turnings.
#
# * Do the Periods within each unique Turning share a similar resemblance to each other?
# * Does each Turning stand out as different or unique from each of the other Turnings: does a "Crisis" (Winter) look different than a First Turning (Spring)?
#
# Plotted on the y-axis is the "score" for each year, and the x-axis is the number of years since the start of the Turning. The score is a measure of the transition of Presidential power from older generations to younger generations. As a new Turning begins, and generation in their Young Adult phase of life transition to Midlife, the score for a Midlife president is 2. As the generation in Midlife transitions into the Elderhood phase of life, the score for new Elderly is 1. And as the prior generation in Elderhood transitions out of civic duty, the score is 0 for those that remain involved. A higher score signifies a President from a more youthful generation.

# %%
# Generational Leadership of the President: Comparison of Periods within a Turnings, and accross Turnings 
figure_1

# %% [markdown]
# Overall, there is really no meaningful relationship to discern from the data when viewed this way. Visually nothing stands out. To formalize an analysis, I used two functions to measure each turning: the average score over each period - a measure of the total youthfulness in the Presidency during the period – and the time it took from the start of the period to elect a Midlife president. Averaging these two measures across each of the four Turnings, and comparing their robustness with a two-sample t-test, shows no distinguishable difference between the Turnings.

# %% [markdown]
# ### American Political Leadership: Congress - Senate and the House
#
# As with the Presidential data, there really is no meaningful relationship to distinguish the different Turnings when looking at the generational composition of Congress. Visually, what stands out is that the more modern periods seems to start out with lower scores - older generations still occupying the seats of Congress at the beginning of a Turning - and slowly progress over time to the more youthful generations – with a higher score. Indeed the data does bore this out - the average age of Congressional leaders has increased from ~44-years old prior to 1850, rising to ~54-years by 1950. Earlier periods saw a younger generational cohort start each period in positions of Congressional leadership, and transition to the next generations within the turning. More modern periods have younger generations being elected to Congress mid-Turning, and sticking around into the next Turning.

# %%
# Generational Leadership of Congress: Comparison of Periods within a Turnings, and accross Turnings 
figure_2

# %% [markdown]
# I was surprised and disappointed by the outcome of the political leadership analysis. I'll come back to this at the end. The economic data was more fruitful.

# %% [markdown]
# ### American Economic Outcomes: GDP-per-Capita & Population Growth
#
# GDP-per-Capita and Population Growth are two important measures that help tell the story of a nation’s prosperity and advancement. These and the Debt-to-GDP data present much more compelling evidence in the seasonality of American history, compared to the political leadership data analyzed above. The chart below shows GDP-per-Capita over the history of the U.S. A log scale is used to help visualize the rate of at which the economy has compounded over time.

# %%
# Total GDP-per-Capita History (log Scale)
figure_6

# %%
# GDP-per-Capita: Comparison of Periods within a Turnings, and accross Turnings 
figure_7

# %% [markdown]
# This data shows that the GDP-per-Capita growth is in fact different across the other Turnings, especially in the Fourth Turning. Given that we are interested in where economic growth accelerated, and where it decelerated, the compound growth of GDP-per-Capita is calculated compared to the beginning of the period, starting at 1.0 (or 100%). Thus, a line that ends at 1.2, for example, would imply that GDP-per-Capita grew by a total of 20% during that time period.
#
# The statistic I used to compare similarities within Turnings and differences across Turnings was the cumulative growth at the 10-year mark, about the midpoint of each Period. The Fourth Turning is arguably the Turning I’m most interested in, since it’s the season of history we currently find ourselves in the middle of. And with abbreviated data on the other Fourth Turnings – the American Revolution and the Civil War – using the 10-year mark allows an analysis to generalize with 2 samples (vs. the other Turnings having 3 samples).

# %%
score_gdp_per_cap_df
# Out:
#                     Mean       Var  Count
# First_Turning   1.097184  0.006160      3
# Second_Turning  1.184269  0.013030      3
# Third_Turning   1.202791  0.001107      3
# Fourth_Turning  1.017562  0.013799      2

# %% [markdown]
# The Fourth Turnings (Financial Crisis and Great Depression & WWII) had the lowest average growth at ~2% vs. 9% in the First Turnings and 18%-20% in the Second and Third Turnings. The results are statistically significant, loosely defined for the small sample sizes. The mean GDP-per-Capita of the Fourth Turning vs. the two most productive Second and Third Turnings were in the outer 1/4th of the t-distribution. This is evidence to suggest that the distribution of GDP-per-Capita outcomes in the Fourth Turning is in fact different. The greatest statistical significance was between the First Turning and Third turning – with the means of the two Turnings being in the ~15% extremes of the t-distribution.

# %%
score_ttest(score_gdp_per_cap_df)
# Out:
#                                    P_Value    t_Stat
# First_Turning_vs_Second_Turning   0.344626 -1.088870
# Second_Turning_vs_Third_Turning   0.809298 -0.269816
# Third_Turning_vs_Fourth_Turning   0.254845  2.172638
# First_Turning_vs_Third_Turning    0.131286 -2.145769
# First_Turning_vs_Fourth_Turning   0.506364  0.841508
# Second_Turning_vs_Fourth_Turning  0.244507  1.572245

# %% [markdown]
# Also interesting, the Fourth Turning had the lowest population growth of the other Turnings – again measured at the 10-year midpoint. The result was noticeable as the other Turnings all saw an average, cumulative population growth of ~22% while the Fourth Turning only saw population growth of 8%. Notably, the population growth during the Financial Crisis period isn’t even noticeable on the graph – as it almost perfectly overlaps the population growth path during the Great Depression & WWII period. The difference in population growth between the slow Fourth Turning and the First and Second turnings are significant at the 15% level, and significant vs. the Third Turning at the 20% level.

# %%
# Population Growth: Comparison of Periods within a Turnings, and accross Turnings 
figure_9

# %%
# The full history of America's population growth (log scale)
figure_600

# %% [markdown]
# ### American Economic Outcomes: Debt-to-GDP
#
# Debt-to-GDP data helps tell the story of whether a nation is borrowing from the future, and its younger generations, or being fiscally prudent. All debt isn’t all-bad, and relabeling “borrowing” “investing” implies a worthy cause – as was the case in WWII to invest in the safety and prosperity of future generations. Also, Debt-to-GDP does not capture the entire story of social liabilities - there are health care burdens, pension burdens, and corporate and consumer debt. However, it does tell a large part of the story, and one directly impacted by the decisions of America's leadership. And the face value of debt does help distinguish periods where the perceived needs exceeded the means.

# %%
figure_100

# %%
# Debt-to-GDP Growth: Comparison of Periods within a Turnings, and accross Turnings 
figure_10

# %% [markdown]
# There is a perfect split in the data, in terms of Debt-to-GDP growth. All of the periods in the First and Second Turnings are in the bottom half of the distribution of cumulative Federal Debt growth, and all of the periods in the Third and Fourth Turnings are in the top half. The chart below shows this more clearly.

# %%
figure_1000

# %% [markdown]
# Analyzing the data, again at the 10-year midpoint, shows that the higher average debt accumulation of the Fourth Turnings is statistically significant at the ~5% level vs. both the First and Second Turnings. The Third Turning is statistically significant vs. all other turnings at the ~15% level, including the Fourth Turning. The Fourth Turnings have seen an average increase in Debt-to-GDP of ~44% of GDP, while the Third Turnings have seen an average increase of ~25%. While the First Turnings had a lower average than the Second Turnings – driven by the major debt repayment of the American High period, the First and Second Turnings are not different from each other at a statistically significant level.

# %%
score_debt_df
# Out:
#                      Mean         Var  Count
# First_Turning  -12.766667  750.923333      3
# Second_Turning   1.966667   35.763333      3
# Third_Turning   24.566667  167.373333      3
# Fourth_Turning  43.800000   54.080000      2

# %%
score_ttest(score_debt_df)
# Out:
#                                    P_Value    t_Stat
# First_Turning_vs_Second_Turning   0.451694 -0.909831
# Second_Turning_vs_Third_Turning   0.076093 -2.746470
# Third_Turning_vs_Fourth_Turning   0.124996 -2.113284
# First_Turning_vs_Third_Turning    0.127325 -2.133860
# First_Turning_vs_Fourth_Turning   0.059290 -3.396630
# Second_Turning_vs_Fourth_Turning  0.024789 -6.702037

# %% [markdown]
# ### American Economic Outcomes: Income Inequality
#
# The level of inequality provides critical insight into the equitability of how the health and wealth of an economy is being distributed between its citizens. This has important implications that influency political outcomes and policy making. And adds an important dimension to the above measures of the size of the economic pie, regarding how it is being distributed.

# %%
# US Income Inequality: Comparison of Periods within a Turnings, and accross Turnings 
figure_15

# %% [markdown]
# Two observations fall out of the income inequaltiy data.
#
# First, the more modern and granular data series for the First and Second Turning show that the income share of the top-10% of US incomes actually declines during much of the period. Data from the 1800's is a linear extrapolation, more on that later. But the two modern periods in the Third turning show a clear and solid upward trend in the income share of the top-10%, and thus a worsening inequality. The two-sample t-test recognizes this difference as well, with an average p-value of 16% between the Third Turning and the First and Second Turnings
#
# The other obvious phenomenon is the huge decrease in top income share during the World War II period. Earlier in this period - the Great Depression - top income shares moved sideways, as they have so far during the Global Financial Crisis period we are in now, and are really not much different than the data in other periods in turnings. Is the World War II period a unique event in history, or is this emblematic of Fourth Turnings?
#
# Coming back the the data from the 1800's, the Third-Turning data is the cleanest. For the Mexican War period - the data point at 1850 is 6 years into the period and the 1860 data point marks the end of the period. And the WWI period only has a linear extrapolation from 1870 - 1913 for the first 5-years of the period, and then has granular yearly data for the remaning 16 years of the period. The Civil War period in the Fourth Turning data splits the linear extrapolation in half, from 1860 (begining of the Civil War) to 1870, 5-years into the Reconstruction and Gilded Age. Thus, there is the possibility that it slopes down, and not up. The Reconstruction and Gilded Age (First Turning) and the subsequent Third Great Awakening (Second Turning) are really the weakest. Combined they have a single data point 1870, with the essencially the entierty of the two periods an extrapolation to the 1913 data point within the WWI period.

# %%
score_inequality_df
# Note: Excludes the current Global Financial Crisis period, since it has not concluded yet
# Out:
#                     Mean        Var  Count
# First_Turning   1.153942   0.487959      2
# Second_Turning  0.257707   2.279997      2
# Third_Turning   4.782306  11.006315      3
# Fourth_Turning -4.273026  49.143173      2

# %%
score_ttest(score_inequality_df)
# Out:
#                                    P_Value    t_Stat
# First_Turning_vs_Second_Turning   0.552946  0.761828
# Second_Turning_vs_Third_Turning   0.134868 -2.063303
# Third_Turning_vs_Fourth_Turning   0.291526  1.703999
# First_Turning_vs_Third_Turning    0.193534 -1.834298
# First_Turning_vs_Fourth_Turning   0.469994  1.089420
# Second_Turning_vs_Fourth_Turning  0.525335  0.893520

# %% [markdown]
# ### Summary: Fourth Turnings Come Along Every ~80-years, And Look Different Economically
#
# Overall, the economic story of America as told by the data is one that follows the theory set out by William Strauss and Neil Howe, with relationships that are powerful enough to be statistically significant, despite the challenges of small sample sizes. As highlighted by the authors, the core elements of a Fourth Turning are “debt, civic decay, global disorder.”
#
# * Debt accumulation is low and almost identical during the First (Spring) and Second (Summer) Turnings, and rises at increasing levels in the Third (Autumn) and Fourth (Winter) Turnings.
#
# * With GDP-per-Capita, a widely used measure of national wealth, the Second and Third Turnings had the greatest average increases in population wealth, and at very similar levels. Meanwhile, the Fourth Turning saw the lowest increase in GDP-per-Capita, at basically nil, which was statistically significant vs. the leading Second and Third Turnings.
#
# * Population Growth showed the Fourth Turnings to be different than all three other seasons of history. The other three Turnings had population growth of 20%+ on average during their full roughly 20-year span. The Fourth Turnings saw less than half that growth (~8%) on average, with the difference being statistically significant at the 15%-20% level.

# %% [markdown]
# ### Summary: Generational Analysis of American Political Leadership Came Up Empty - For Now
#
# Sadly, I was not able to find compelling evidence of a link between the generational identities of American political leadership and a broader cycle of American history. However, there was some evidence of the generational Archetypes. It was noticeable was that the Hero and Prophet Archetypes do seem to be elected to Presidential power more often than the other two. American political leadership plays such an important roll in William Strauss and Neil Howe's Fourth Turning prophecy. I’ll share some it here to convey my motivations for this project.

# %% [markdown]
# ### Summary: William Strauss and Neil Howe's Fourth Turning Playbook:
#
# The transition from the Third Turning (the "Unraveling") to the Fourth Turning (the "Crisis") begins with the catalyst. "In the pre-Crisis years, fears about the flimsiness of the social contrac will have been subliminal but rising. As the Crisis catalyzes, these fears will rush to the surface, jagged and exposed. At the Crisis catalyst, the Silent [generation] will be out of authority, Boomers will be nearing their peak of power, 13ers will be rapidly ascending, and Millennials will be fledgling voters and soldiers. Time will pass, perhaps another decade, before the surging mood propels America to the Fourth Turning's grave moment of opportunity and danger: the climax of the Crisis. Eventually, all of America's lesser problems will combine into one giant problem. At or just after the Crisi climax, 13ers [Generation X] will supplant Boomers in national leadership. When the Crisis resolves, the silent will have no power, Boomers on the brink of a steep descent, 13ers near their peak, Millenials rapidly ascending, and the New Silend [Homelanders generation] just starting to vote and join the military."

# %%
# Congressional Leadership in The Financial Crisis Period 
congress_fourth_turning_df = congress_turnings_dict['Fourth_Turning']
congress_current_turning_df = congress_fourth_turning_df[congress_fourth_turning_df['Period'] == 'Global Financial Crisis']
congress_current_turning_df = congress_current_turning_df[:'2020'].fillna(0)

figure_200, ax = plt.subplots(figsize=(10,5))
sns.lineplot(data=congress_current_turning_df, x='Year', y='Prophet', ax=ax, linewidth=5, );
sns.lineplot(data=congress_current_turning_df, x='Year', y='Nomad', ax=ax, linewidth=5, );
sns.lineplot(data=congress_current_turning_df, x='Year', y='Hero', ax=ax, linewidth=5, );
sns.set_palette('icefire')
ax.set_title('Congressional Leadership in The Financial Crisis Period', fontsize=20);
ax.legend(['Boomer', 'Gen_X', 'Millenial']);

# %%
# Congressional Leadership in The Great Depression WWII Period
#congress_fourth_turning_df = congress_turnings_dict['Fourth_Turning']
congress_last_fourth_turning_df = congress_fourth_turning_df[congress_fourth_turning_df['Period'] == 'Great Depression & World War II']
# congress_current_turning_df = congress_current_turning_df[:'2020'].fillna(0)

figure_200, ax = plt.subplots(figsize=(10,5))
sns.lineplot(data=congress_last_fourth_turning_df, x='Year', y='Prophet', ax=ax, linewidth=5);  
# PuOr, viridis, PRGn, RdBu, icefire
sns.lineplot(data=congress_last_fourth_turning_df, x='Year', y='Nomad', ax=ax, linewidth=5);
sns.lineplot(data=congress_last_fourth_turning_df, x='Year', y='Hero', ax=ax, linewidth=5);
sns.set_palette('icefire')
ax.set_title('Congressional Leadership in The Great Depression WWII Period', fontsize=20);
ax.legend(['Prophet (Boomer)', 'Nomad (Gen_X)', 'Hero (Millenial)']);
